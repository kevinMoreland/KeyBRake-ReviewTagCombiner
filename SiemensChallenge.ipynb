# %%
# !pip install nltk
# !pip install rake_nltk
# Out:
# ...
#   Created wheel for rake-nltk: filename=rake_nltk-1.0.4-py2.py3-none-any.whl size=7819 sha256=b393e1f8acb5819c5e6c481b5bc6968dc15c6194e4cc16b2ca98b8cd12a467e9
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# ...

# %%
import nltk 
import numpy as np
import pandas as pd
import json
import requests
from rake_nltk import Rake

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
json_data = pd.read_json('/content/drive/MyDrive/HackOff Project/Cell_Phones_and_Accessories_5.json', lines = True)
json_data
# Out:
#             reviewerID        asin  ... unixReviewTime   reviewTime
# 0       A30TL5EWN6DFXT  120401325X  ...     1400630400  05 21, 2014
# 1        ASY55RVNIL0UD  120401325X  ...     1389657600  01 14, 2014
# 2       A2TMXE2AFO7ONB  120401325X  ...     1403740800  06 26, 2014
# 3        AWJ0WZQYMYFQ4  120401325X  ...     1382313600  10 21, 2013
# 4        ATX7CZYFXI1KW  120401325X  ...     1359849600   02 3, 2013
# ...                ...         ...  ...            ...          ...
# 194434  A1YMNTFLNDYQ1F  B00LORXVUE  ...     1405900800  07 21, 2014
# 194435  A15TX8B2L8B20S  B00LORXVUE  ...     1405900800  07 21, 2014
# 194436  A3JI7QRZO1QG8X  B00LORXVUE  ...     1405900800  07 21, 2014
# 194437  A1NHB2VC68YQNM  B00LORXVUE  ...     1405814400  07 20, 2014
# 194438  A1AG6U022WHXBF  B00LORXVUE  ...     1405900800  07 21, 2014
#
# [194439 rows x 9 columns]

# %%
def get_keywords(text):
  rake = Rake()
  rake.extract_keywords_from_text(text)
  return rake.get_ranked_phrases_with_scores()

# %%
json_data['keywords'] = json_data.apply(lambda row: get_keywords(row['reviewText']), axis = 1)

# %%
json_data['keywords'][1]
# Out:
# [(9.0, 'stickers work like'),
#  (4.0, 'super stylish'),
#  (4.0, 'review says'),
#  (1.0, 'stick'),
#  (1.0, 'stay'),
#  (1.0, 'sister'),
#  (1.0, 'share'),
#  (1.0, 'phone'),
#  (1.0, 'great'),
#  (1.0, ':)')]
